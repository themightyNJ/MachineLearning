# %% [markdown]
# <a href="https://colab.research.google.com/github/themightyNJ/MachineLearning/blob/master/GlobalWarming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objects as go
import chart_studio.plotly as py
import plotly.express as px
# !pip install pycountry
import pycountry

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# ...
#      |████████████████████████████████| 10.0MB 12.3MB/s
# ...
#   Created wheel for pycountry: filename=pycountry-19.8.18-py2.py3-none-any.whl size=10627360 sha256=157f649142130ce59630ee08732c38490d0485d1a13bade0bda86ce6aa23786e
#   Stored in directory: /root/.cache/pip/wheels/a2/98/bf/f0fa1c6bf8cf2cbdb750d583f84be51c2cd8272460b8b36bd3
# Successfully built pycountry
# ...
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_csv(r"https://raw.githubusercontent.com/themightyNJ/MachineLearning/master/emission_data.csv")
data = data.drop(index = 227)

# %%
data1 = pd.read_csv(r"https://raw.githubusercontent.com/themightyNJ/MachineLearning/master/emission_data.csv")
data1 = data1.iloc[227:228]
data1
# Out:
#     Country     1751      1752  ...          2015          2016          2017
# 227   World  9350528  18704720  ...  1.500000e+12  1.540000e+12  1.580000e+12
#
# [1 rows x 268 columns]

# %%
Countries = data["Country"]
keys = ["Country","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017"]

# %%
nation = []
for i in range(230):
    nation.append(data[keys].iloc[i])

# %%
filter_nation = []
for i in range(len(nation)):
    filter_nation.append(nation[i].iloc[1:])

# %%
for i in range(len(nation)):
    filter_nation[i].plot.bar()
    plt.title(Countries[i])
    plt.xlabel("Year")
    plt.ylabel("Amount of Gas Emission")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-19f1cadf27e9> in <module>()
#       1 for i in range(len(nation)):
#       2     filter_nation[i].plot.bar()
# ----> 3     plt.title(Countries[i])
#       4     plt.xlabel("Year")
#       5     plt.ylabel("Amount of Gas Emission")
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
# ...

# %%
pycountry.countries.search_fuzzy(data.Country.iloc[0])[0].alpha_3
# Out:
# 'AFG'

# %%
some_countries = ["England", "HerpaDerpaland", "Engla"]

def do_fuzzy_search(country):
    try:
        result = pycountry.countries.search_fuzzy(country)
        return result[0].alpha_3
    except:
        return np.nan

for country in some_countries:
    print(do_fuzzy_search(country))
# Out:
# GBR
# nan
# GBR

# %%
data['country_code'] = data["Country"].apply(lambda country: do_fuzzy_search(country))

# %%
plot_df = data.dropna()
fig = px.choropleth(plot_df, locations="country_code",
                    color="1817",
                    hover_name="Country",
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="74fa7cc2-cb2d-4f5b-ae12-8357da7099b1" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("74fa7cc2-cb2d-4f5b-ae12-8357da7099b1")) {
#                     Plotly.newPlot(
#                         '74fa7cc2-cb2d-4f5b-ae12-8357da7099b1',
# ...

# %%
plot_df = data.dropna()
fig = px.choropleth(plot_df, locations="country_code",
                    color="1867",
                    hover_name="Country",
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="96bd1a45-6867-48d8-aeb6-4ce6842d3562" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("96bd1a45-6867-48d8-aeb6-4ce6842d3562")) {
#                     Plotly.newPlot(
#                         '96bd1a45-6867-48d8-aeb6-4ce6842d3562',
# ...

# %%
plot_df = data.dropna()
fig = px.choropleth(plot_df, locations="country_code",
                    color="1993",
                    hover_name="Country",
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="02bc94d9-df24-421b-b3a6-891f309fdf24" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("02bc94d9-df24-421b-b3a6-891f309fdf24")) {
#                     Plotly.newPlot(
#                         '02bc94d9-df24-421b-b3a6-891f309fdf24',
# ...

# %%
plot_df = data.dropna()
fig = px.choropleth(plot_df, locations="country_code",
                    color="2007",
                    hover_name="Country",
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0a99295a-8ca1-4d6f-9796-982385508f05" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0a99295a-8ca1-4d6f-9796-982385508f05")) {
#                     Plotly.newPlot(
#                         '0a99295a-8ca1-4d6f-9796-982385508f05',
# ...

# %%
plot_df = data.dropna()
fig = px.choropleth(plot_df, locations="country_code",
                    color="2017",
                    hover_name="Country",
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a9111749-9967-4881-92f3-688f55689d4b" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a9111749-9967-4881-92f3-688f55689d4b")) {
#                     Plotly.newPlot(
#                         'a9111749-9967-4881-92f3-688f55689d4b',
# ...

# %%
data["2017"].plot()
plt.title("World in 2017")
plt.xlabel("Country Sequence")
plt.ylabel("Amount of Gas Emission")
plt.show()
