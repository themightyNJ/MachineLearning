# %%
import seaborn as s

# %%
tips = s.load_dataset("tips")
iris= s.load_dataset("iris")

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
a = s.barplot(tips["tip"],tips["total_bill"])

# %%
b = s.barplot(tips["day"],tips["total_bill"],data=tips,hue='time')

# %%
b = s.barplot(tips["day"],tips["total_bill"],data=tips,hue='time',palette='winter',ci=None)
#ci removes the Error bar.
#Error bar depicts the uncertainity in given data.

# %%
import numpy as np
num=np.random.randn(130)
s.boxplot(num)

# %%
num2 = np.random.randn(9,9)
num2
# Out:
# array([[ 0.10159304, -1.18418313,  0.28481046,  1.43609226,  0.01158797,
#         -0.26883984, -0.75272681,  0.36391113,  1.62832375],
#        [ 0.23112036, -0.83324433, -0.67414254, -0.06400957, -0.03433878,
#         -0.41886207,  0.65507854, -0.17870432, -0.32484749],
#        [ 1.1614424 ,  0.03454541, -0.97082603, -0.972987  ,  0.05967574,
#         -1.82581571, -1.23719011, -0.1806159 ,  1.05451707],
#        [ 0.38002877, -1.23954702,  2.02355335, -0.64915133, -0.575859  ,
#          0.58043234, -0.29118365,  0.93319375,  0.48077339],
#        [-0.84969502,  1.0601835 , -0.66055299,  0.12577073,  0.0218371 ,
#          0.7050131 ,  1.30418869,  1.13203588, -1.45059076],
#        [ 0.09386846,  1.18169112,  0.23444788,  2.33453278,  0.70403586,
#         -0.19784651,  0.15245395,  0.08381801, -0.37283425],
#        [ 0.75017626, -0.40604768,  1.17264846, -1.55911867,  0.83804456,
#          0.42634933,  1.42171975, -0.05703467, -1.01444292],
# ...

# %%
s.heatmap(num2,annot = True)

# %%
s.regplot(tips["tip"],tips["total_bill"])

# %%
import pandas as pd 
df = pd.DataFrame(tips)

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
s.pairplot(tips)

# %%
x = [1,2,3]
y = [4,5,6]

# %%
np.std(x)
# Out:
# 0.816496580927726

# %%
np.std(y)
# Out:
# 0.816496580927726

# %%
np.mean(x)
# Out:
# 2.0

# %%
np.median(x)
# Out:
# 2.0

# %%
np.var(x)
# Out:
# 0.6666666666666666

# %%
dff = {"1":x,"2":y}

# %%
pd.DataFrame(dff).corr()
# Out:
#      1    2
# 1  1.0  1.0
# 2  1.0  1.0

# %%
a = pd.DataFrame(dff)
a
# Out:
#    1  2
# 0  1  4
# 1  2  5
# 2  3  6

# %%
s.regplot(x="1",y="2",data = a)

# %%
b1 = -1.0 * (np.std(y)/np.std(x))
b1
# Out:
# -1.0

# %%
b0 = np.mean(y) - b1 * np.mean(x)
b0
# Out:
# 7.0

# %%
Y = b0 +b1*4

# %%
Y
# Out:
# 3.0
